# %% [markdown]
# <a href="https://colab.research.google.com/github/indudhara59/R-Collab/blob/main/R_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x <- 5
print(x)
print(x + 5)
# Out:
# [1] 5
# [1] 10

# %%
a <- c(1,2,3,4,5)
b <- 1:5
c <- b + 1
print(c + a + 1)
# Out:
# [1]  4  6  8 10 12

# %%
c <- c(1,2,3)
print(c)
# Out:
# [1] 1 2 3
